# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.ambeedata.com/weather/forecast/by-lat-lng?lat=12&lng=77&filter=hourly&x-api-key=09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477")
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'message': 'success',
#  'data': {'lat': 12,
#   'lng': 77,
#   'forecast': [{'timezone': 'Asia/Kolkata',
#     'time': 1725552000,
#     'apparentTemperature': 71,
#     'cloudCover': 0.74,
#     'dewPoint': 66.62,
#     'humidity': 85,
#     'pressure': 1011,
#     'precipIntensity': 0,
#     'temperature': 71,
#     'visibility': 10,
#     'windGust': 18.85,
#     'ozone': 273.68,
#     'uvIndex': 0,
#     'windSpeed': 8.57,
#     'windBearing': 260,
#     'icon': 'cloudy',
#     'summary': 'Cloudy skies. Temperatures will feel warm. Higher humidity levels. Expect a gentle breeze. Low UV levels.'},
#    {'timezone': 'Asia/Kolkata',
#     'time': 1725555600,
#     'apparentTemperature': 70,
#     'cloudCover': 0.93,
#     'dewPoint': 66.65,
#     'humidity': 87,
#     'pressure': 1012,
#     'precipIntensity': 0,
#     'temperature': 70,
#     'visibility': 10,
#     'windGust': 16.83,
#     'ozone': 273.8,
#     'uvIndex': 0,
#     'windSpeed': 7.17,
#     'windBearing': 257,
# ...

# %%
# import http.client

# conn = http.client.HTTPSConnection("api.ambeedata.com")

# headers = {
#     'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
#     'Content-type': "application/json"
#     }

# conn.request("GET", "/disasters/latest/by-country-code?countryCode=IND&limit=50&page=1", headers=headers)

# res = conn.getresponse()
# data = res.read()

# data.decode("utf-8")

# %%
# import http.client

# conn = http.client.HTTPSConnection("api.ambeedata.com")

# headers = {
#     'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
#     'Content-type': "application/json"
#     }

# conn.request("GET", "/disasters/latest/by-country-code?countryCode=IND&limit=50&page=2", headers=headers)

# res = conn.getresponse()
# data = res.read()

# data.decode("utf-8")

# %%
# import http.client

# conn = http.client.HTTPSConnection("api.ambeedata.com")

# headers = {
#     'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
#     'Content-type': "application/json"
#     }

# conn.request("GET", "/disasters/latest/by-country-code?countryCode=USA&limit=50&page=2", headers=headers)

# res = conn.getresponse()
# data = res.read()

# data.decode("utf-8")

# %% [markdown]
# ### Continent to search for events. Can be should be one of AFR, ANT, ASIA, AUS, EUR, NAR, SAR, OCEAN

# %%
import http.client


conn = http.client.HTTPSConnection("api.ambeedata.com")

headers = {
    'x-api-key': "08af8b0cedf4f975507cb122476f0d32846546b9a06b4b5688e2632197afb32c",
    'Content-type': "application/json"
    }

conn.request("GET", "/disasters/latest/by-continent?continent=NAR&limit=50&page=1", headers=headers)

# %%
res = conn.getresponse()
data = res.read()
data = data.decode("utf-8")
json_data = json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 data = res.read()
#       3 data = data.decode("utf-8")
# ----> 4 json_data = json.loads(data)
#
# NameError: name 'json' is not defined

# %%
json_data
# Out:
# {'message': 'success',
#  'hasNextPage': True,
#  'page': 1,
#  'limit': 50,
#  'result': [{'event_type': 'EQ',
#    'event_name': 'NORTHERN ALASKA',
#    'date': '2024-09-05 12:00:00',
#    'lat': 65.8812,
#    'continent': 'nar',
#    'country_code': 'USA',
#    'created_time': '2024-09-05 14:35:56',
#    'lng': -152.2179,
#    'source_event_id': '11881331',
#    'event_id': '66c703fd72c3d1a4e41443e0'},
#   {'event_type': 'DR',
#    'event_name': 'Drought in Guatemala, Honduras, Mexico, Nicaragua',
#    'date': '2024-09-05 00:00:00',
#    'lat': 18.5,
#    'continent': 'nar',
#    'country_code': 'MEX',
#    'created_time': '2024-09-05 14:35:56',
#    'lng': -99,
#    'source_event_id': '1016963',
#    'event_id': '66c703f672c3d1a4e413d41a'},
#   {'event_type': 'DR',
#    'event_name': 'Drought in Canada',
#    'date': '2024-09-05 00:00:00',
#    'lat': 53.5,
#    'continent': 'nar',
#    'country_code': 'CAN',
#    'created_time': '2024-09-05 14:35:56',
#    'lng': -116,
# ...

# %%
data = pd.DataFrame(json_data['result'])[['event_type','event_name','date','lat','lng','continent','country_code','created_time']]
data
# Out:
#    event_type                                         event_name  \
# 0          EQ                                    NORTHERN ALASKA
# 1          DR  Drought in Guatemala, Honduras, Mexico, Nicaragua
# 2          DR                                  Drought in Canada
# 3          EQ                    CALIFORNIA-NEVADA BORDER REGION
# 4          EQ                                 CENTRAL CALIFORNIA
# 5          EQ                                             NEVADA
# 6          EQ                                 CENTRAL CALIFORNIA
# 7          EQ                                            MONTANA
# 8          EQ                    CALIFORNIA-NEVADA BORDER REGION
# 9          EQ                                     SOUTHERN TEXAS
# 10         EQ                                             OREGON
# 11         EQ                                            MONTANA
# 12         EQ                                           OKLAHOMA
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 11):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=NAR&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df
# Out:
#     event_type                                         event_name  \
# 0           EQ                                    NORTHERN ALASKA
# 1           DR  Drought in Guatemala, Honduras, Mexico, Nicaragua
# 2           DR                                  Drought in Canada
# 3           EQ                    CALIFORNIA-NEVADA BORDER REGION
# 4           EQ                                 CENTRAL CALIFORNIA
# ..         ...                                                ...
# 482         WF                  Element Wildfire, Mohave, Arizona
# 483         WF                         Wildfire in Canada 1020976
# 484         WF                         Wildfire in Canada 1021013
# 485         WF                         Wildfire in Canada 1021011
# 486         EQ  M 3.4 - 77 km W of The Bottom, Bonaire, Saint ...
#
#                     date        lat         lng continent country_code  \
# 0    2024-09-05 12:00:00  65.881200 -152.217900       nar          USA
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['country_code'].unique()
# Out:
# array(['USA', 'MEX', 'CAN', 'PAN', 'ATG', 'GRL', 'CRI', 'BRB', 'JAM',
#        'AIA', 'TCA', 'BMU', 'FRA', 'CUB', 'HND', 'VIR'], dtype=object)

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 11):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=ASIA&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df1 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df1
# Out:
#     event_type                           event_name                 date  \
# 0           SW              Moderate Rain at Raipur  2024-09-05 14:00:00
# 1           SW                 Heavy Rain at Bhopal  2024-09-05 14:00:00
# 2           SW              Moderate Rain at Raipur  2024-09-05 14:00:00
# 3           SW                    Lightning at SDMA  2024-09-05 14:00:00
# 4           SW                 Light Rain at Mumbai  2024-09-05 13:00:00
# ..         ...                                  ...                  ...
# 495         EQ              Earthquake in Indonesia  2024-08-12 11:00:00
# 496         ET       Extremely Heavy Rain at Jaipur  2024-08-12 07:00:00
# 497         EQ      M 4.3 - 17 km SSW of Fasā, Iran  2024-08-12 06:00:00
# 498         EQ  M 4.4 - 111 km SSE of Honchō, Japan  2024-08-12 05:00:00
# 499         FL                    Flood in Malaysia  2024-08-12 01:00:00
#
#            lat         lng continent country_code         created_time
# ...

# %%
df1['country_code'].unique()
# Out:
# array(['IND', 'BGD', 'JPN', 'PHL', 'HKG', 'AZE', 'RUS', 'TUR', 'CHN',
#        'CYP', 'IDN', 'OMN', 'NPL', 'PAK', 'AFG', 'THA', 'KGZ', 'MYS',
#        'KOR', 'SYR', 'IRN', 'VNM'], dtype=object)

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(11, 21):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=ASIA&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df3 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df3
# Out:
#     event_type                                     event_name  \
# 0         Misc  Moderate cloud to ground Lightning at Lucknow
# 1           TC                     Tropical Cyclone WUKONG-24
# 2           SW                                  Typhoon Ampil
# 3           EQ     M 4.6 - 77 km W of Sungai Penuh, Indonesia
# 4           EQ          M 4.3 - 17 km SW of Nabire, Indonesia
# ..         ...                                            ...
# 108         TN                               tsunami in JAPAN
# 109         WF             Forest fires in Russian Federation
# 110         EQ          M 4.4 - 65 km NNE of Mawlaik, Myanmar
# 111         SW                         Heavy Rain at Dehradun
# 112         EQ       M 4.3 - 94 km NNE of Namuac, Philippines
#
#                     date        lat         lng continent country_code  \
# 0    2024-08-14 01:00:00  27.153928   82.402841      asia          IND
# 1    2024-08-14 00:00:00  34.872677  147.737490      asia          JPN
# ...

# %%
df3['country_code'].unique()
# Out:
# array(['IND', 'JPN', 'IDN', 'VNM', 'SYR', 'RUS', 'TUR', 'IRN', 'MYS',
#        'BTN', 'ARM', 'AFG', 'PHL', 'KGZ', 'CHN', 'MMR'], dtype=object)

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 6):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=SAR&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df2 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df2
# Out:
#    event_type                                         event_name  \
# 0          EQ           M 5.7 - 61 km WSW of Challapata, Bolivia
# 1          DR  Drought in Bolivia, Brazil, Colombia, Guyana, ...
# 2          WF                             Forest fires in Brazil
# 3          EQ              M 4.8 - Off the coast of Aisen, Chile
# 4          EQ                 M 5.3 - southeast of Easter Island
# ..        ...                                                ...
# 89         EQ                M 4.6 - 47 km NW of Aroa, Venezuela
# 90         EQ              M 4.3 - 48 km NNE of Santa Rosa, Peru
# 91         EQ              M 3.9 - 71 km SSW of La Tirana, Chile
# 92         WF                         Wildfire in Brazil 1020965
# 93         WF                         Wildfire in Brazil 1021051
#
#                    date        lat         lng continent country_code  \
# 0   2024-09-05 10:00:00 -19.076091  -67.303800       sar          BOL
# ...

# %%
df2['country_code'].unique()
# Out:
# array(['BOL', 'BRA', 'CHL', 'ARG', 'ECU', 'PER', 'FRA', 'PRY', 'VEN'],
#       dtype=object)

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 2):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=ANT&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df4 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df4
# Out:
#   event_type                        event_name                 date  \
# 0         EQ   M 5.4 - Pacific-Antarctic Ridge  2024-08-29 20:00:00
# 1         EQ           M 5.5 - south of Africa  2024-08-23 04:00:00
# 2         EQ                    Earthquake in   2024-08-23 04:00:00
# 3         SI                      Iceberg B22G  2024-08-15 00:00:00
# 4         EQ  M 4.3 - west of Macquarie Island  2024-08-08 06:00:00
#
#          lat         lng continent country_code         created_time
# 0 -62.776791 -158.195300       ant          ATA  2024-09-05 14:35:56
# 1 -52.862391   21.042700       ant          ATA  2024-09-05 14:35:56
# 2 -52.937500   19.477102       ant          ATA  2024-08-24 14:36:19
# 3 -72.410991 -127.080000       ant          ATA  2024-09-05 14:35:56
# 4 -56.140091  146.923600       ant          ATA  2024-09-05 14:35:56

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 11):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=AFR&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df5 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df5
# Out:
#    event_type                                         event_name  \
# 0          DR  Drought in Burkina Faso, Cote d'Ivoire, Ghana,...
# 1          DR        Drought in Algeria, Spain, Morocco, Tunisia
# 2          DR                              Drought in Madagascar
# 3          DR  Drought in Angola, Democratic Republic of Cong...
# 4          DR         Drought in Botswana, Namibia, South Africa
# ..        ...                                                ...
# 75         WF                         Wildfire in Angola 1021261
# 76         WF                     Wildfire in Mozambique 1021247
# 77         WF                         Forest fires in Mozambique
# 78         WF                       Wildfire in Tanzania 1020800
# 79         WF                         Wildfire in Angola 1021069
#
#                    date        lat        lng continent country_code  \
# 0   2024-09-05 00:00:00  10.496000  -2.000000       afr          GHA
# ...

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 6):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=EUR&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df6 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df6
# Out:
#    event_type                                         event_name  \
# 0          DR  Drought in Bulgaria, Belarus, Czech Republic, ...
# 1          EQ                M 5.0 - 109 km WNW of Höfn, Iceland
# 2          EQ                 M 4.1 - 25 km NW of Itháki, Greece
# 3          EQ                              M 4.4 - Greenland Sea
# 4          FL                                     Flood in Italy
# 5          FL                                   Flood in Austria
# 6          EQ                M 4.4 - 24 km NNE of Cariati, Italy
# 7        Misc            Mass movement in Campania Region, Italy
# 8          EQ                 M 4.5 - 18 km E of Istiaía, Greece
# 9          EQ                            M 4.5 - Svalbard region
# 10         EQ                 M 5.4 - 52 km W of Sines, Portugal
# 11         EQ                             Earthquake in Portugal
# 12         VO                                Eruption  Reykjanes
# ...

# %%
df6['country_code'].unique()
# Out:
# array(['UKR', 'ISL', 'GRC', 'NOR', 'ITA', 'AUT', 'PRT', 'ESP', 'SRB',
#        'SVK', 'POL', 'IRL', 'BEL', 'HRV', 'DEU', 'FRA', 'ROU', 'EST'],
#       dtype=object)

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 6):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=AUS&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df7 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df7
# Out:
#     event_type                                        event_name  \
# 0         Misc                              Burn Off, CUMMING RD
# 1         Misc                  Rescue, NINGALOO-YARDIE CREEK RD
# 2           WF                               Bushfire, HADLEY RD
# 3         Misc              Vehicle Fire, NORTH WEST COASTAL HWY
# 4           EQ    M 6.2 - 66 km NNE of Angoram, Papua New Guinea
# ..         ...                                               ...
# 99          EQ                   M 4.1 - Kermadec Islands region
# 100         EQ  M 4.8 - 121 km SSE of Lorengau, Papua New Guinea
# 101         WF                         Forest fires in Australia
# 102         EQ             M 4.2 - south of the Kermadec Islands
# 103         WF              Wildfire in Papua New Guinea 1021077
#
#                     date        lat         lng continent country_code  \
# 0    2024-09-05 13:00:00 -32.221516  115.891831       aus          AUS
# ...

# %%
import http.client
import json
import pandas as pd

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
}

all_data = []

for i in range(1, 6):
    conn = http.client.HTTPSConnection("api.ambeedata.com")
    conn.request("GET", f"/disasters/latest/by-continent?continent=OCEAN&limit=50&page={i}", headers=headers)
    
    res = conn.getresponse()
    data = res.read()
    data = data.decode("utf-8")
    json_data = json.loads(data)

    if 'result' in json_data:
        all_data.extend(json_data['result'])
    
    conn.close()

# Create DataFrame from the collected data
df8 = pd.DataFrame(all_data)[['event_type', 'event_name', 'date', 'lat', 'lng', 'continent', 'country_code', 'created_time']]
df8
# Out:
#   event_type                             event_name                 date  \
# 0         EQ    M 4.8 - northern Mid-Atlantic Ridge  2024-09-01 15:00:00
# 1         EQ  M 4.7 - South Sandwich Islands region  2024-08-22 01:00:00
# 2         EQ    M 5.0 - southern Mid-Atlantic Ridge  2024-08-21 06:00:00
# 3         TC            Tropical Cyclone ERNESTO-24  2024-08-20 15:00:00
# 4         EQ    M 4.7 - South Georgia Island region  2024-08-18 08:00:00
# 5         FL                      Flood in Maldives  2024-08-15 01:00:00
# 6         EQ     M 4.4 - Mauritius - Reunion region  2024-08-09 10:00:00
# 7         EQ  M 4.5 - South Sandwich Islands region  2024-08-07 11:00:00
#
#          lat        lng continent country_code         created_time
# 0  26.431409 -44.561300     ocean          PRT  2024-09-05 14:35:39
# 1 -55.960091 -30.779200     ocean          SGS  2024-09-05 14:35:39
# 2 -16.572091 -14.570600     ocean          SHN  2024-09-05 14:35:39
# ...

# %%
disaster = pd.concat([data,df,df1,df2,df3,df4,df5,df6,df7,df8], axis=0, ignore_index=True)
disaster.to_csv("disaster_data.csv")

# %%
disaster
# Out:
#      event_type                                         event_name  \
# 0            EQ                                    NORTHERN ALASKA
# 1            DR  Drought in Guatemala, Honduras, Mexico, Nicaragua
# 2            DR                                  Drought in Canada
# 3            EQ                    CALIFORNIA-NEVADA BORDER REGION
# 4            EQ                                 CENTRAL CALIFORNIA
# ...         ...                                                ...
# 1474         TC                        Tropical Cyclone ERNESTO-24
# 1475         EQ                M 4.7 - South Georgia Island region
# 1476         FL                                  Flood in Maldives
# 1477         EQ                 M 4.4 - Mauritius - Reunion region
# 1478         EQ              M 4.5 - South Sandwich Islands region
#
#                      date        lat         lng continent country_code  \
# 0     2024-09-05 12:00:00  65.881200 -152.217900       nar          USA
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("api.ambeedata.com")

headers = {
    'x-api-key': "09a5c00568c2d46e92365e5640dfac275d0ce75cfc6b4115f12890c3e3347477",
    'Content-type': "application/json"
    }

conn.request("GET", "/disasters/history/by-continent?continent=NAR&from=2023-05-01%2020%3A16%3A44&to=2024-06-01%2000%3A00%3A00&limit=10&page=1", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"message":"No active subscription found"}
